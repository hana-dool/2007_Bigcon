# %% [markdown]
# # import modules

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
import datetime
import time

# %% [markdown]
# # Data set 불러오기

# %%
# 여러분의 폴더가 저장되어있는 위치 경로를 써 주세요
# 그리고 데이터파일(주최측에서 제공한) 의 이름을 Train set 으로 변셩해 주세요
# 한인욱 directory = 'C:/Users/goran/Desktop/Git_Hub/Project/20S_Bigcon'
directory = 'C:/Users/goran/Desktop/Git_Hub/Project/20S_Bigcon'

# %%
# 그러면 이렇게 그 폴더 안의 Train set.xlsx 을 잘 읽어옵니다! 
X_df=pd.read_excel(directory+'/Train set.xlsx',header = 1)

# %%
# 데이터 reset 하고싶으면 위의 셀 말고 이거 돌려가면서 reset 하세요! 그게 제일 빨라요
X = X_df.copy()

# %%
X.head()
# Out:
#                  방송일시  노출(분)    마더코드    상품코드            상품명 상품군   판매단가  \
# 0 2019-01-01 06:00:00   20.0  100346  201072  테이트 남성 셀린니트3종  의류  39900
# 1 2019-01-01 06:00:00    NaN  100346  201079  테이트 여성 셀린니트3종  의류  39900
# 2 2019-01-01 06:20:00   20.0  100346  201072  테이트 남성 셀린니트3종  의류  39900
# 3 2019-01-01 06:20:00    NaN  100346  201079  테이트 여성 셀린니트3종  의류  39900
# 4 2019-01-01 06:40:00   20.0  100346  201072  테이트 남성 셀린니트3종  의류  39900
#
#          취급액
# 0  2099000.0
# 1  4371000.0
# 2  3262000.0
# 3  6955000.0
# 4  6672000.0

# %% [markdown]
# # 20200805 결측치 처리 과정

# %%
X.isnull().sum()
# Out:
# 방송일시         0
# 노출(분)    16784
# 마더코드         0
# 상품코드         0
# 상품명          0
# 상품군          0
# 판매단가         0
# 취급액        937
# dtype: int64

# %% [markdown]
# #### 상품군 곁측치 처리

# %% [markdown]
#  판매단가가 0 인 상품은 예측에서 제외

# %%
def NA_goods(df=X):
    df=df.loc[df['판매단가'] != 0,:]
    df = df.reset_index(drop=True)
    return df

# %%
NA_goods(X)
# Out:
#                      방송일시  노출(분)    마더코드    상품코드             상품명 상품군    판매단가  \
# 0     2019-01-01 06:00:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# 1     2019-01-01 06:00:00    NaN  100346  201079   테이트 여성 셀린니트3종  의류   39900
# 2     2019-01-01 06:20:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# 3     2019-01-01 06:20:00    NaN  100346  201079   테이트 여성 셀린니트3종  의류   39900
# 4     2019-01-01 06:40:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# ...                   ...    ...     ...     ...             ...  ..     ...
# 37367 2019-12-31 23:40:00    NaN  100448  201391   일시불쿠첸압력밥솥 6인용  주방  148000
# 37368 2020-01-01 00:00:00   20.0  100448  201383  무이자쿠첸압력밥솥 10인용  주방  178000
# 37369 2020-01-01 00:00:00    NaN  100448  201390  일시불쿠첸압력밥솥 10인용  주방  168000
# 37370 2020-01-01 00:00:00    NaN  100448  201384   무이자쿠첸압력밥솥 6인용  주방  158000
# 37371 2020-01-01 00:00:00    NaN  100448  201391   일시불쿠첸압력밥솥 6인용  주방  148000
#
#                취급액
# 0        2099000.0
# 1        4371000.0
# 2        3262000.0
# 3        6955000.0
# 4        6672000.0
# ...            ...
# 37367   10157000.0
# 37368   50929000.0
# 37369  104392000.0
# 37370   13765000.0
# 37371   46608000.0
#
# [37372 rows x 8 columns]

# %% [markdown]
# #### 노출(분) 곁측치 처리

# %% [markdown]
# 노출분은 같은 시간에 같이 방송되어서 NaN 으로 뜨는것이다. <br>
# 아마 같은 시간에 방송되어진 값을 평균해서 채우면 될듯?

# %%
# 0 노출시간이 0 인 데이터가 없다.
# 즉 Na 처리할떄 0으로 대채한 후에 평균떄려도 아무 상관 없다는 이야기!
(X.loc[:,'노출(분)']==0).sum()
# Out:
# 0

# %%
# 노출(분) 을 제일 먼저 시작한 시간의 값으로 만드는 FUNCTION 정의
# 아직 맞는지는 잘 몰라서 안맞는 경우 수정해주세요.
def NA_minute(df=X):
    # 곁측치를 0으로 대체
    df['노출(분)'] = df['노출(분)'].fillna(0)
    
    count_0 = [] 
    count_not0 = [] # 0이 아닌 수의 index
    for idx in df.index :
        if df.loc[idx,'노출(분)'] == 0 :
            count_0.append(idx)
        else :
            count_not0.append(idx)
    count_not0.append(len(df)) # 맨 마지막 열에 0 인 경우를 대비하여

    for idx,x in enumerate(count_not0):
        if idx != len(count_not0)-1: 
            if (count_not0[idx+1] - count_not0[idx] - 1) != 0:
                start = count_not0[idx] 
                end = count_not0[idx+1]
                num = end - start 
                df.loc[start:(end-1),'노출(분)'] = df.loc[start,'노출(분)'] # / num 을 붙여주면 평균으로 만들게 됩니다.
    return df

# %%
NA_minute(X)
# Out:
#                      방송일시      노출(분)    마더코드    상품코드  \
# 0     2019-01-01 06:00:00  20.000000  100346  201072
# 1     2019-01-01 06:00:00  20.000000  100346  201079
# 2     2019-01-01 06:20:00  20.000000  100346  201072
# 3     2019-01-01 06:20:00  20.000000  100346  201079
# 4     2019-01-01 06:40:00  20.000000  100346  201072
# ...                   ...        ...     ...     ...
# 38304 2020-01-01 00:20:00  20.000000  100073  200196
# 38305 2020-01-01 00:40:00  20.000000  100073  200196
# 38306 2020-01-01 01:00:00  20.000000  100073  200196
# 38307 2020-01-01 01:20:00  20.000000  100490  201478
# 38308 2020-01-01 01:40:00  17.166667  100490  201478
#
#                             상품명 상품군   판매단가        취급액
# 0                 테이트 남성 셀린니트3종  의류  39900  2099000.0
# 1                 테이트 여성 셀린니트3종  의류  39900  4371000.0
# 2                 테이트 남성 셀린니트3종  의류  39900  3262000.0
# 3                 테이트 여성 셀린니트3종  의류  39900  6955000.0
# 4                 테이트 남성 셀린니트3종  의류  39900  6672000.0
# ...                         ...  ..    ...        ...
# 38304  삼성화재 행복한파트너 주택화재보험(1912)  무형      0        NaN
# 38305  삼성화재 행복한파트너 주택화재보험(1912)  무형      0        NaN
# 38306  삼성화재 행복한파트너 주택화재보험(1912)  무형      0        NaN
# 38307        더케이 예다함 상조서비스(티포트)  무형      0        NaN
# 38308        더케이 예다함 상조서비스(티포트)  무형      0        NaN
#
# [38309 rows x 8 columns]

# %% [markdown]
# ####  토요일 곁측치 처리

# %% [markdown]
# 매주 토요일 18:00~18:20은 정보방송시간으로 추정 제외(당사사정에 따라 ±20 편성 변경 있음)

# %%
def NA_Saturday(df = X):
    t = ['월','화','수','목','금','토','일']
    r = datetime.datetime.today()
    def printDayOfTheWeek(year, month, day):
        dayOfTheWeek = ['월','화','수','목','금','토','일']
        return dayOfTheWeek[datetime.datetime(year,month,day).weekday()]
    day_list = []
    for date in X.iloc[:,0]:
        date = str(date)
        year = int(date[:4])
        month = int(date[5:7])
        day = int(date[8:10])
        first = printDayOfTheWeek(year,month,day)
        second = date[11:16]
        day_list.append(first+second)
    X["요일/시간"] = day_list
    for i in range(len(df)):
        time = df.iloc[i,8]
        if (time[0:3]=="토18" and int(time[4:])<20):
            df = df.drop(i)
    return df

# %%
#check 하는 용도라 뺴놨습니다!
for i in range(len(NA_Saturday(X))):
    time = X.iloc[i,8]
    if time[0:3]=="토18":
        print(time)
# Out:
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:50
# 토18:20
# 토18:40
# 토18:20
# 토18:50
# 토18:20
# 토18:40
# 토18:20
# 토18:50
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:50
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:30
# 토18:40
# 토18:50
# 토18:20
# 토18:50
# 토18:20
# 토18:30
# 토18:40
# 토18:50
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:50
# 토18:20
# 토18:40
# 토18:20
# 토18:20
# 토18:20
# 토18:20
# 토18:20
# 토18:20
# 토18:40
# 토18:40
# 토18:40
# 토18:40
# 토18:40
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40
# 토18:20
# 토18:40

# %% [markdown]
# 힘들게 코드를 짰으나 토요일 18:00~18:20에 해당하는 방송은 없었다.............................

# %% [markdown]
# #### 취급액 50000-> 0 처리

# %%
(X.loc[:,'취급액'] <= 50000).sum()
# Out:
# 1993

# %%
def NA_50000(df=X):
    df.loc[df.loc[:,'취급액'] <= 50000 ,'취급액'] = 0
    return df

# %%
NA_50000(X)
# Out:
#                      방송일시      노출(분)    마더코드    상품코드  \
# 0     2019-01-01 06:00:00  20.000000  100346  201072
# 1     2019-01-01 06:00:00  20.000000  100346  201079
# 2     2019-01-01 06:20:00  20.000000  100346  201072
# 3     2019-01-01 06:20:00  20.000000  100346  201079
# 4     2019-01-01 06:40:00  20.000000  100346  201072
# ...                   ...        ...     ...     ...
# 38304 2020-01-01 00:20:00  20.000000  100073  200196
# 38305 2020-01-01 00:40:00  20.000000  100073  200196
# 38306 2020-01-01 01:00:00  20.000000  100073  200196
# 38307 2020-01-01 01:20:00  20.000000  100490  201478
# 38308 2020-01-01 01:40:00  17.166667  100490  201478
#
#                             상품명 상품군   판매단가        취급액   요일/시간
# 0                 테이트 남성 셀린니트3종  의류  39900  2099000.0  화06:00
# 1                 테이트 여성 셀린니트3종  의류  39900  4371000.0  화06:00
# 2                 테이트 남성 셀린니트3종  의류  39900  3262000.0  화06:20
# 3                 테이트 여성 셀린니트3종  의류  39900  6955000.0  화06:20
# 4                 테이트 남성 셀린니트3종  의류  39900  6672000.0  화06:40
# ...                         ...  ..    ...        ...     ...
# 38304  삼성화재 행복한파트너 주택화재보험(1912)  무형      0        NaN  수00:20
# 38305  삼성화재 행복한파트너 주택화재보험(1912)  무형      0        NaN  수00:40
# 38306  삼성화재 행복한파트너 주택화재보험(1912)  무형      0        NaN  수01:00
# 38307        더케이 예다함 상조서비스(티포트)  무형      0        NaN  수01:20
# 38308        더케이 예다함 상조서비스(티포트)  무형      0        NaN  수01:40
#
# [38309 rows x 9 columns]

# %% [markdown]
# #### 곁측치 처리 pipeline

# %%
def Na_pipeline(df = X):
    df = NA_goods(df)
    df = NA_minute(df)
    df = NA_Saturday(df)
    df = NA_50000(df)
    return(df)

# %%
X = Na_pipeline(X) ; X
# Out:
#                      방송일시  노출(분)    마더코드    상품코드             상품명 상품군    판매단가  \
# 0     2019-01-01 06:00:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# 1     2019-01-01 06:00:00   20.0  100346  201079   테이트 여성 셀린니트3종  의류   39900
# 2     2019-01-01 06:20:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# 3     2019-01-01 06:20:00   20.0  100346  201079   테이트 여성 셀린니트3종  의류   39900
# 4     2019-01-01 06:40:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# ...                   ...    ...     ...     ...             ...  ..     ...
# 37367 2019-12-31 23:40:00   20.0  100448  201391   일시불쿠첸압력밥솥 6인용  주방  148000
# 37368 2020-01-01 00:00:00   20.0  100448  201383  무이자쿠첸압력밥솥 10인용  주방  178000
# 37369 2020-01-01 00:00:00   20.0  100448  201390  일시불쿠첸압력밥솥 10인용  주방  168000
# 37370 2020-01-01 00:00:00   20.0  100448  201384   무이자쿠첸압력밥솥 6인용  주방  158000
# 37371 2020-01-01 00:00:00   20.0  100448  201391   일시불쿠첸압력밥솥 6인용  주방  148000
#
#                취급액   요일/시간
# 0        2099000.0  화06:00
# 1        4371000.0  화06:00
# 2        3262000.0  화06:20
# 3        6955000.0  화06:20
# 4        6672000.0  화06:40
# ...            ...     ...
# 37367   10157000.0  화23:40
# 37368   50929000.0  수00:00
# 37369  104392000.0  수00:00
# 37370   13765000.0  수00:00
# 37371   46608000.0  수00:00
#
# [37372 rows x 9 columns]

# %%
# na 없다
X.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # 데이터 살펴보기

# %% [markdown]
# 노출 분은 대부분 10 분 내외인듯.

# %%
pd.DataFrame(pd.Series(X['노출(분)']).value_counts(normalize=True))
# Out:
#               노출(분)
# 20.000000  0.882853
# 30.000000  0.051670
# 10.000000  0.021727
# 30.100000  0.018543
# 15.000000  0.009178
# ...             ...
# 26.683333  0.000027
# 25.216667  0.000027
# 8.850000   0.000027
# 26.166667  0.000027
# 27.083333  0.000027
#
# [102 rows x 1 columns]

# %% [markdown]
# # 변수 늘리기

# %% [markdown]
# #### 시간 데이터 늘리기

# %%
# 시각은 우선 시,분을 합쳐서 하나의 값으로 만들었습니다.
def time_feature(df = X):
    df['방송일시']=df['방송일시'].astype('str')
    df['날짜']=df['방송일시'].str.split(' ').str[0]
    df['시간']=df['방송일시'].str.split(' ').str[1]
    df['년']=df['날짜'].str.split('-').str[0]
    df['월']=df['날짜'].str.split('-').str[1]
    df['일']=df['날짜'].str.split('-').str[2]
    df['시']=df['시간'].str.split(':').str[0]
    df['분']=df['시간'].str.split(':').str[1]
    df['초']=df['시간'].str.split(':').str[2]
    df['시각'] = df['시'].astype('float32') + df['분'].astype('float32')*(1/60)
    df.drop(['시','분','초','시간'],axis=1,inplace = True)
    return(df)

# %%
X = time_feature(X) ; X
# Out:
#                       방송일시  노출(분)    마더코드    상품코드             상품명 상품군    판매단가  \
# 0      2019-01-01 06:00:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# 1      2019-01-01 06:00:00   20.0  100346  201079   테이트 여성 셀린니트3종  의류   39900
# 2      2019-01-01 06:20:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# 3      2019-01-01 06:20:00   20.0  100346  201079   테이트 여성 셀린니트3종  의류   39900
# 4      2019-01-01 06:40:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# ...                    ...    ...     ...     ...             ...  ..     ...
# 37367  2019-12-31 23:40:00   20.0  100448  201391   일시불쿠첸압력밥솥 6인용  주방  148000
# 37368  2020-01-01 00:00:00   20.0  100448  201383  무이자쿠첸압력밥솥 10인용  주방  178000
# 37369  2020-01-01 00:00:00   20.0  100448  201390  일시불쿠첸압력밥솥 10인용  주방  168000
# 37370  2020-01-01 00:00:00   20.0  100448  201384   무이자쿠첸압력밥솥 6인용  주방  158000
# 37371  2020-01-01 00:00:00   20.0  100448  201391   일시불쿠첸압력밥솥 6인용  주방  148000
#
#                취급액   요일/시간          날짜     년   월   일         시각
# 0        2099000.0  화06:00  2019-01-01  2019  01  01   6.000000
# 1        4371000.0  화06:00  2019-01-01  2019  01  01   6.000000
# 2        3262000.0  화06:20  2019-01-01  2019  01  01   6.333333
# 3        6955000.0  화06:20  2019-01-01  2019  01  01   6.333333
# 4        6672000.0  화06:40  2019-01-01  2019  01  01   6.666667
# ...            ...     ...         ...   ...  ..  ..        ...
# 37367   10157000.0  화23:40  2019-12-31  2019  12  31  23.666666
# 37368   50929000.0  수00:00  2020-01-01  2020  01  01   0.000000
# 37369  104392000.0  수00:00  2020-01-01  2020  01  01   0.000000
# 37370   13765000.0  수00:00  2020-01-01  2020  01  01   0.000000
# 37371   46608000.0  수00:00  2020-01-01  2020  01  01   0.000000
#
# [37372 rows x 14 columns]

# %% [markdown]
# #### 식사 시간과 관련된 변수

# %% [markdown]
# 식사시간의 경우 유의미한 데이터가 있을 수 있다. 그 시간대를 잡아서 변수를 늘리면 효과가 있을거같다. <br>
# 하지만 아침 식사시간의 경우 거르는 인구가 33%(통계청) 이나 되는 이유로, 오히려 혼란을 가중시킬 수 있기떄문에 그냥 점심과 저녁만 고려하자

# %%
def eat_feature(df = X):
    df['점심'] = 0
    df.loc[ (11.5<df['시각']) & (df['시각'] < 13),'점심']  = 1
    df['저녁'] = 0
    df.loc[ (17.5<df['시각'])&(df['시각']<19.5) , '저녁'] = 1
    return(df)

# %%
X = eat_feature(X) ; X
# Out:
#                       방송일시  노출(분)    마더코드    상품코드             상품명 상품군    판매단가  \
# 0      2019-01-01 06:00:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# 1      2019-01-01 06:00:00   20.0  100346  201079   테이트 여성 셀린니트3종  의류   39900
# 2      2019-01-01 06:20:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# 3      2019-01-01 06:20:00   20.0  100346  201079   테이트 여성 셀린니트3종  의류   39900
# 4      2019-01-01 06:40:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# ...                    ...    ...     ...     ...             ...  ..     ...
# 37367  2019-12-31 23:40:00   20.0  100448  201391   일시불쿠첸압력밥솥 6인용  주방  148000
# 37368  2020-01-01 00:00:00   20.0  100448  201383  무이자쿠첸압력밥솥 10인용  주방  178000
# 37369  2020-01-01 00:00:00   20.0  100448  201390  일시불쿠첸압력밥솥 10인용  주방  168000
# 37370  2020-01-01 00:00:00   20.0  100448  201384   무이자쿠첸압력밥솥 6인용  주방  158000
# 37371  2020-01-01 00:00:00   20.0  100448  201391   일시불쿠첸압력밥솥 6인용  주방  148000
#
#                취급액   요일/시간          날짜     년   월   일         시각  점심  저녁
# 0        2099000.0  화06:00  2019-01-01  2019  01  01   6.000000   0   0
# 1        4371000.0  화06:00  2019-01-01  2019  01  01   6.000000   0   0
# 2        3262000.0  화06:20  2019-01-01  2019  01  01   6.333333   0   0
# 3        6955000.0  화06:20  2019-01-01  2019  01  01   6.333333   0   0
# 4        6672000.0  화06:40  2019-01-01  2019  01  01   6.666667   0   0
# ...            ...     ...         ...   ...  ..  ..        ...  ..  ..
# 37367   10157000.0  화23:40  2019-12-31  2019  12  31  23.666666   0   0
# 37368   50929000.0  수00:00  2020-01-01  2020  01  01   0.000000   0   0
# 37369  104392000.0  수00:00  2020-01-01  2020  01  01   0.000000   0   0
# 37370   13765000.0  수00:00  2020-01-01  2020  01  01   0.000000   0   0
# 37371   46608000.0  수00:00  2020-01-01  2020  01  01   0.000000   0   0
#
# [37372 rows x 16 columns]

# %%
pd.Series(X['점심']).value_counts() # 좀 sparse 하긴 한데 의미는 있을거라고 믿는다...
# Out:
# 0    35025
# 1     2347
# Name: 점심, dtype: int64

# %% [markdown]
# #### 강수량 변수

# %% [markdown]
# 날씨 데이터의 경우 기상청의 공공데이터를 사용했다.
# 일별 기온(평균기온, 최고기온, 최저기온), 일별 강수량, 월별 기상정보(폭염일수, 열대야일수)를 고려했다.

# %%
rain_df=pd.read_csv(directory+'/19rain.csv',header = 7, encoding='CP949')
rain = rain_df.copy()

# %%
rain.head()
# Out:
#            날짜  지점  강수량(mm)
# 0  2019-01-01  전국      0.1
# 1  2019-01-02  전국      0.0
# 2  2019-01-03  전국      0.0
# 3  2019-01-04  전국      0.0
# 4  2019-01-05  전국      0.0

# %%
def rain_feature(df = X):
       
    df = pd.merge(df, rain, on="날짜", how= "inner")
    df.drop(['지점'],axis=1,inplace = True)
    return(df)

X = rain_feature(X) ; X
# Out:
#                       방송일시  노출(분)    마더코드    상품코드             상품명 상품군    판매단가  \
# 0      2019-01-01 06:00:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# 1      2019-01-01 06:00:00   20.0  100346  201079   테이트 여성 셀린니트3종  의류   39900
# 2      2019-01-01 06:20:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# 3      2019-01-01 06:20:00   20.0  100346  201079   테이트 여성 셀린니트3종  의류   39900
# 4      2019-01-01 06:40:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# ...                    ...    ...     ...     ...             ...  ..     ...
# 37367  2019-12-31 23:40:00   20.0  100448  201391   일시불쿠첸압력밥솥 6인용  주방  148000
# 37368  2020-01-01 00:00:00   20.0  100448  201383  무이자쿠첸압력밥솥 10인용  주방  178000
# 37369  2020-01-01 00:00:00   20.0  100448  201390  일시불쿠첸압력밥솥 10인용  주방  168000
# 37370  2020-01-01 00:00:00   20.0  100448  201384   무이자쿠첸압력밥솥 6인용  주방  158000
# 37371  2020-01-01 00:00:00   20.0  100448  201391   일시불쿠첸압력밥솥 6인용  주방  148000
#
#                취급액   요일/시간          날짜     년   월   일         시각  점심  저녁  \
# 0        2099000.0  화06:00  2019-01-01  2019  01  01   6.000000   0   0
# 1        4371000.0  화06:00  2019-01-01  2019  01  01   6.000000   0   0
# 2        3262000.0  화06:20  2019-01-01  2019  01  01   6.333333   0   0
# 3        6955000.0  화06:20  2019-01-01  2019  01  01   6.333333   0   0
# 4        6672000.0  화06:40  2019-01-01  2019  01  01   6.666667   0   0
# ...            ...     ...         ...   ...  ..  ..        ...  ..  ..
# 37367   10157000.0  화23:40  2019-12-31  2019  12  31  23.666666   0   0
# 37368   50929000.0  수00:00  2020-01-01  2020  01  01   0.000000   0   0
# 37369  104392000.0  수00:00  2020-01-01  2020  01  01   0.000000   0   0
# 37370   13765000.0  수00:00  2020-01-01  2020  01  01   0.000000   0   0
# 37371   46608000.0  수00:00  2020-01-01  2020  01  01   0.000000   0   0
#
#        강수량(mm)
# 0          0.1
# 1          0.1
# 2          0.1
# 3          0.1
# 4          0.1
# ...        ...
# 37367      0.1
# 37368      0.0
# 37369      0.0
# 37370      0.0
# 37371      0.0
#
# [37372 rows x 17 columns]

# %% [markdown]
# #### 온도 변수

# %%
temp_df=pd.read_csv(directory+'/19temp.csv',header = 7, encoding='CP949')
temp = temp_df.copy()

# %%
temp.head()
# Out:
#            날짜  지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0  2019-01-01  전국     -2.1     -5.8      2.1
# 1  2019-01-02  전국     -2.5     -7.0      3.2
# 2  2019-01-03  전국     -2.1     -7.7      5.0
# 3  2019-01-04  전국     -0.7     -7.3      5.3
# 4  2019-01-05  전국      0.2     -4.6      5.3

# %%
def temp_feature(df = X):
    df = pd.merge(df, temp, on="날짜", how= "inner")
    df.drop(['지점'],axis=1,inplace = True)
    return(df)
X = temp_feature(X) ; X
# Out:
#                       방송일시  노출(분)    마더코드    상품코드             상품명 상품군    판매단가  \
# 0      2019-01-01 06:00:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# 1      2019-01-01 06:00:00   20.0  100346  201079   테이트 여성 셀린니트3종  의류   39900
# 2      2019-01-01 06:20:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# 3      2019-01-01 06:20:00   20.0  100346  201079   테이트 여성 셀린니트3종  의류   39900
# 4      2019-01-01 06:40:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# ...                    ...    ...     ...     ...             ...  ..     ...
# 37367  2019-12-31 23:40:00   20.0  100448  201391   일시불쿠첸압력밥솥 6인용  주방  148000
# 37368  2020-01-01 00:00:00   20.0  100448  201383  무이자쿠첸압력밥솥 10인용  주방  178000
# 37369  2020-01-01 00:00:00   20.0  100448  201390  일시불쿠첸압력밥솥 10인용  주방  168000
# 37370  2020-01-01 00:00:00   20.0  100448  201384   무이자쿠첸압력밥솥 6인용  주방  158000
# 37371  2020-01-01 00:00:00   20.0  100448  201391   일시불쿠첸압력밥솥 6인용  주방  148000
#
#                취급액   요일/시간          날짜     년   월   일         시각  점심  저녁  \
# 0        2099000.0  화06:00  2019-01-01  2019  01  01   6.000000   0   0
# 1        4371000.0  화06:00  2019-01-01  2019  01  01   6.000000   0   0
# 2        3262000.0  화06:20  2019-01-01  2019  01  01   6.333333   0   0
# 3        6955000.0  화06:20  2019-01-01  2019  01  01   6.333333   0   0
# 4        6672000.0  화06:40  2019-01-01  2019  01  01   6.666667   0   0
# ...            ...     ...         ...   ...  ..  ..        ...  ..  ..
# 37367   10157000.0  화23:40  2019-12-31  2019  12  31  23.666666   0   0
# 37368   50929000.0  수00:00  2020-01-01  2020  01  01   0.000000   0   0
# 37369  104392000.0  수00:00  2020-01-01  2020  01  01   0.000000   0   0
# 37370   13765000.0  수00:00  2020-01-01  2020  01  01   0.000000   0   0
# 37371   46608000.0  수00:00  2020-01-01  2020  01  01   0.000000   0   0
#
#        강수량(mm)  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0          0.1     -2.1     -5.8      2.1
# 1          0.1     -2.1     -5.8      2.1
# 2          0.1     -2.1     -5.8      2.1
# 3          0.1     -2.1     -5.8      2.1
# 4          0.1     -2.1     -5.8      2.1
# ...        ...      ...      ...      ...
# 37367      0.1     -3.8     -6.7      0.4
# 37368      0.0      4.1     -6.5      4.1
# 37369      0.0      4.1     -6.5      4.1
# 37370      0.0      4.1     -6.5      4.1
# 37371      0.0      4.1     -6.5      4.1
#
# [37372 rows x 20 columns]

# %% [markdown]
# #### 폭염 변수

# %%
hot_df=pd.read_csv(directory+'/19hot.csv',header = 4, encoding='CP949')
hot = hot_df.copy()

# %%
hot
# Out:
#              월  평균 열대야일수  평균 폭염일수
# 0   2019-01-01       0.0      0.0
# 1   2019-01-02       0.0      0.0
# 2   2019-01-03       0.0      0.0
# 3   2019-01-04       0.0      0.0
# 4   2019-01-05       0.0      0.1
# 5   2019-01-06       0.0      0.6
# 6   2019-01-07       4.7      3.9
# 7   2019-01-08       5.8      5.3
# 8   2019-01-09       0.4      0.2
# 9   2019-01-10       0.0      0.0
# 10  2019-01-11       0.0      0.0
# 11  2019-01-12       0.0      0.0

# %%
hot['월']=hot['월'].str.split('-').str[2]

# %%
hot.head()
# Out:
#     월  평균 열대야일수  평균 폭염일수
# 0  01       0.0      0.0
# 1  02       0.0      0.0
# 2  03       0.0      0.0
# 3  04       0.0      0.0
# 4  05       0.0      0.1

# %%
def hot_feature(df = X):   
    df = pd.merge(df, hot, on="월", how= "inner", right_index=True)
    return(df)
X = hot_feature(X) ; X
# Out:
#                       방송일시  노출(분)    마더코드    상품코드             상품명 상품군    판매단가  \
# 0      2019-01-01 06:00:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# 1      2019-01-01 06:00:00   20.0  100346  201079   테이트 여성 셀린니트3종  의류   39900
# 2      2019-01-01 06:20:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# 3      2019-01-01 06:20:00   20.0  100346  201079   테이트 여성 셀린니트3종  의류   39900
# 4      2019-01-01 06:40:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# ...                    ...    ...     ...     ...             ...  ..     ...
# 37363  2019-12-31 23:20:00   20.0  100448  201391   일시불쿠첸압력밥솥 6인용  주방  148000
# 37364  2019-12-31 23:40:00   20.0  100448  201383  무이자쿠첸압력밥솥 10인용  주방  178000
# 37365  2019-12-31 23:40:00   20.0  100448  201390  일시불쿠첸압력밥솥 10인용  주방  168000
# 37366  2019-12-31 23:40:00   20.0  100448  201384   무이자쿠첸압력밥솥 6인용  주방  158000
# 37367  2019-12-31 23:40:00   20.0  100448  201391   일시불쿠첸압력밥솥 6인용  주방  148000
#
#               취급액   요일/시간          날짜  ...   일         시각 점심  저녁  강수량(mm)  \
# 0       2099000.0  화06:00  2019-01-01  ...  01   6.000000  0   0      0.1
# 1       4371000.0  화06:00  2019-01-01  ...  01   6.000000  0   0      0.1
# 2       3262000.0  화06:20  2019-01-01  ...  01   6.333333  0   0      0.1
# 3       6955000.0  화06:20  2019-01-01  ...  01   6.333333  0   0      0.1
# 4       6672000.0  화06:40  2019-01-01  ...  01   6.666667  0   0      0.1
# ...           ...     ...         ...  ...  ..        ... ..  ..      ...
# 37363   1664000.0  화23:20  2019-12-31  ...  31  23.333334  0   0      0.1
# 37364   9149000.0  화23:40  2019-12-31  ...  31  23.666666  0   0      0.1
# 37365  15282000.0  화23:40  2019-12-31  ...  31  23.666666  0   0      0.1
# 37366   2328000.0  화23:40  2019-12-31  ...  31  23.666666  0   0      0.1
# 37367  10157000.0  화23:40  2019-12-31  ...  31  23.666666  0   0      0.1
#
#        평균기온(℃)  최저기온(℃)  최고기온(℃)  평균 열대야일수  평균 폭염일수
# 0         -2.1     -5.8      2.1       0.0      0.0
# 1         -2.1     -5.8      2.1       0.0      0.0
# 2         -2.1     -5.8      2.1       0.0      0.0
# 3         -2.1     -5.8      2.1       0.0      0.0
# 4         -2.1     -5.8      2.1       0.0      0.0
# ...        ...      ...      ...       ...      ...
# 37363     -3.8     -6.7      0.4       0.0      0.0
# 37364     -3.8     -6.7      0.4       0.0      0.0
# 37365     -3.8     -6.7      0.4       0.0      0.0
# 37366     -3.8     -6.7      0.4       0.0      0.0
# 37367     -3.8     -6.7      0.4       0.0      0.0
#
# [37372 rows x 22 columns]

# %% [markdown]
# #### 연얘인 변수

# %% [markdown]
# ## Feature 늘리기 Pipeline

# %%
def celebrity(df=X):
    df['연예인']=0
    list_celebrity=["전지현", "팽현숙", "전철우", "강레오", "김선영", "김정배", "김규흔", "이봉원", "오세득", "유귀열", "이경제", "이만기", "이보은", "임성근", "전철우", "최인선", "김병만", "김병지", "이동수", "그렉노먼", "서장훈", "송도순", "효재", "천수봉"]
    for i in list_celebrity:
        df.loc[df.상품명.str.contains(i),'연예인']=1
    return df

# %%
X=celebrity(X); X
# Out:
#                       방송일시  노출(분)    마더코드    상품코드             상품명 상품군    판매단가  \
# 0      2019-01-01 06:00:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# 1      2019-01-01 06:00:00   20.0  100346  201079   테이트 여성 셀린니트3종  의류   39900
# 2      2019-01-01 06:20:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# 3      2019-01-01 06:20:00   20.0  100346  201079   테이트 여성 셀린니트3종  의류   39900
# 4      2019-01-01 06:40:00   20.0  100346  201072   테이트 남성 셀린니트3종  의류   39900
# ...                    ...    ...     ...     ...             ...  ..     ...
# 37363  2019-12-31 23:20:00   20.0  100448  201391   일시불쿠첸압력밥솥 6인용  주방  148000
# 37364  2019-12-31 23:40:00   20.0  100448  201383  무이자쿠첸압력밥솥 10인용  주방  178000
# 37365  2019-12-31 23:40:00   20.0  100448  201390  일시불쿠첸압력밥솥 10인용  주방  168000
# 37366  2019-12-31 23:40:00   20.0  100448  201384   무이자쿠첸압력밥솥 6인용  주방  158000
# 37367  2019-12-31 23:40:00   20.0  100448  201391   일시불쿠첸압력밥솥 6인용  주방  148000
#
#               취급액   요일/시간          날짜  ...         시각 점심 저녁  강수량(mm)  평균기온(℃)  \
# 0       2099000.0  화06:00  2019-01-01  ...   6.000000  0  0      0.1     -2.1
# 1       4371000.0  화06:00  2019-01-01  ...   6.000000  0  0      0.1     -2.1
# 2       3262000.0  화06:20  2019-01-01  ...   6.333333  0  0      0.1     -2.1
# 3       6955000.0  화06:20  2019-01-01  ...   6.333333  0  0      0.1     -2.1
# 4       6672000.0  화06:40  2019-01-01  ...   6.666667  0  0      0.1     -2.1
# ...           ...     ...         ...  ...        ... .. ..      ...      ...
# 37363   1664000.0  화23:20  2019-12-31  ...  23.333334  0  0      0.1     -3.8
# 37364   9149000.0  화23:40  2019-12-31  ...  23.666666  0  0      0.1     -3.8
# 37365  15282000.0  화23:40  2019-12-31  ...  23.666666  0  0      0.1     -3.8
# 37366   2328000.0  화23:40  2019-12-31  ...  23.666666  0  0      0.1     -3.8
# 37367  10157000.0  화23:40  2019-12-31  ...  23.666666  0  0      0.1     -3.8
#
#        최저기온(℃)  최고기온(℃)  평균 열대야일수  평균 폭염일수  연예인
# 0         -5.8      2.1       0.0      0.0    0
# 1         -5.8      2.1       0.0      0.0    0
# 2         -5.8      2.1       0.0      0.0    0
# 3         -5.8      2.1       0.0      0.0    0
# 4         -5.8      2.1       0.0      0.0    0
# ...        ...      ...       ...      ...  ...
# 37363     -6.7      0.4       0.0      0.0    0
# 37364     -6.7      0.4       0.0      0.0    0
# 37365     -6.7      0.4       0.0      0.0    0
# 37366     -6.7      0.4       0.0      0.0    0
# 37367     -6.7      0.4       0.0      0.0    0
#
# [37372 rows x 23 columns]

# %%
X.loc[X.상품명.str.contains("팽현숙"),'연예인']
print(X.sum().연예인) #연예인 이름을 사용한 총 데이터 수
# Out:
# 1030
